# %% [markdown]
# # 수면(Water) 세그멘테이션 학습 **v3** — YOLO26m-seg + 얼리스톱
#
# v2(yolo26n-seg) 대비 변경점
# - 모델: `yolo26n-seg` → **`yolo26m-seg`** (폴백 26s → 26n)
# - **얼리스톱**: `EPOCHS=300` 상한 + `patience=40`, 실제 중단 시점 확인 셀 추가
# - 저장 경로 분리: `runs_water_v3` / `water_seg_v3_best.pt`
# - **픽셀 IoU·Dice 평가** 추가 (인스턴스 mAP보다 이 과제에 적합)
# - **conf 임계값 튜닝** 추가 (v2는 Recall이 낮았음)
# - 배치 4 + AMP + RAM 캐싱, `copy_paste` 증강 추가
#
# **v2 기준선**: TEST mask mAP50 0.6042 / mAP50-95 0.3831, VAL 0.7202 / 0.5177

# %% [markdown]
# ## 1. 설치 및 환경 확인

# %%
# 최초 1회만 실행 (이미 설치되어 있으면 건너뛰세요)
# !pip install ultralytics opencv-python numpy pyyaml matplotlib tqdm

# %%
import os, sys, json, shutil, random
from pathlib import Path
from collections import defaultdict, Counter

import numpy as np
import cv2
import torch

print("Python :", sys.version.split()[0])
print("PyTorch:", torch.__version__)
print("CUDA   :", torch.cuda.is_available(),
      "|", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")

try:
    import ultralytics
    print("Ultralytics:", ultralytics.__version__)
except ImportError:
    print("[!] ultralytics 미설치 → 위 셀의 pip install 실행 필요")
# Out:
# Python : 3.11.9
# PyTorch: 2.12.0.dev20260408+cu128
# CUDA   : True | NVIDIA GeForce RTX 5060 Laptop GPU
# Ultralytics: 8.4.86

# %% [markdown]
# ## 2. 경로 설정 (여기만 수정하면 됩니다)

# %%
CFG = {
    # 원본 Roboflow 데이터 (train / valid / test 하위폴더)
    "SRC_ROOT": r"C:\Project\PythonProject\PyTorch001\datasets\water_raw",

    # 변환된 YOLO 형식 데이터셋
    "DST_ROOT": r"C:\Project\PythonProject\PyTorch001\datasets\water_seg",

    # v3 저장 경로 (v2와 분리)
    "RUN_PROJECT": r"C:\Project\PythonProject\PyTorch001\runs_water_v3",
    "RUN_NAME": "water_seg_v3_m",
    "EXPORT_NAME": "water_seg_v3_best.pt",

    # 모델 / 학습 (RTX 5060 Laptop 8GB)
    "MODEL": "yolo26m-seg.pt",  # 폴백: 26s -> 26n
    "IMGSZ": 640,
    "EPOCHS": 300,              # 상한만 크게 두고 얼리스톱이 끊도록
    "PATIENCE": 40,             # 얼리스톱: 40 epoch 개선 없으면 중단
    "BATCH": 4,                 # medium은 8GB에서 batch 8이 위험 -> 4로 시작
    "CACHE": "ram",             # 567장 소용량 -> RAM 캐싱으로 I/O 제거

    # 폴리곤 변환 파라미터
    "MIN_AREA_RATIO": 0.0005,
    "APPROX_EPS_RATIO": 0.002,
}

SRC_ROOT = Path(CFG["SRC_ROOT"])
DST_ROOT = Path(CFG["DST_ROOT"])
SPLITS = ["train", "valid", "test"]

assert SRC_ROOT.exists(), f"경로 없음: {SRC_ROOT}"
for s in SPLITS:
    p = SRC_ROOT / s / "_annotations.coco.json"
    n_img = len(list((SRC_ROOT / s).glob("*.jpg"))) if (SRC_ROOT / s).exists() else 0
    print(f"{s:6s} | json={p.exists()} | images={n_img}")
# Out:
# train  | json=True | images=421
# valid  | json=True | images=92
# test   | json=True | images=54

# %% [markdown]
# ### 2-1. 사전 점검 — 다운로드가 온전한지 먼저 확인
#
# 변환을 돌리기 전에 JSON과 실제 파일 개수가 맞는지 대조합니다.
# `JSON 이미지 수 == 디스크 JPG 수` 여야 하고, 3개 split 합계가 README에 적힌 총 장수와 같아야 합니다.

# %%
total_img = total_ann = 0
for split in SPLITS:
    d = SRC_ROOT / split
    j = d / "_annotations.coco.json"
    if not j.exists():
        print(f"{split:6s} | [!] JSON 없음"); continue
    coco = json.loads(j.read_text(encoding="utf-8"))
    n_json = len(coco["images"])
    n_disk = len(list(d.glob("*.jpg")))
    with_ann = len({a["image_id"] for a in coco["annotations"]})
    flag = "OK " if n_json == n_disk else "MISMATCH"
    print(f"{split:6s} | {flag} | JSON {n_json:4d} / 디스크 {n_disk:4d} | "
          f"라벨있음 {with_ann:4d} | 어노 {len(coco['annotations']):4d}")
    total_img += n_json; total_ann += len(coco["annotations"])

print(f"\n합계: 이미지 {total_img} / 어노테이션 {total_ann}")
print("→ README.roboflow.txt 에 적힌 장수와 일치하는지 확인하세요")
# Out:
# train  | OK  | JSON  421 / 디스크  421 | 라벨있음  421 | 어노  519
# valid  | OK  | JSON   92 / 디스크   92 | 라벨있음   91 | 어노  102
# test   | OK  | JSON   54 / 디스크   54 | 라벨있음   54 | 어노   63
#
# 합계: 이미지 567 / 어노테이션 684
# → README.roboflow.txt 에 적힌 장수와 일치하는지 확인하세요

# %% [markdown]
# ## 3. COCO RLE → 폴리곤 변환 유틸
#
# `pycocotools`가 설치되어 있으면 그것을 쓰고, 없으면 **순수 파이썬 RLE 디코더**로 대체합니다.
# (Windows에서 `pycocotools` 빌드가 자주 실패하므로 의존성 없이 동작하도록 구성했습니다.)

# %%
def _rle_decode_py(counts_str, size):
    '''압축 COCO RLE 문자열 → (H, W) uint8 바이너리 마스크. pycocotools 없이 동작.'''
    h, w = size
    cnts, m, p = [], 0, 0
    while p < len(counts_str):
        x, k, more = 0, 0, 1
        while more:
            c = ord(counts_str[p]) - 48
            x |= (c & 0x1F) << (5 * k)
            more = c & 0x20
            p += 1
            k += 1
            if not more and (c & 0x10):
                x |= (-1 << (5 * k))
        if m > 2:
            x += cnts[m - 2]
        cnts.append(x)
        m += 1

    flat = np.zeros(h * w, dtype=np.uint8)
    idx, val = 0, 0
    for c in cnts:
        flat[idx:idx + c] = val
        idx += c
        val ^= 1
    return flat.reshape((w, h)).T  # COCO RLE은 column-major


try:
    from pycocotools import mask as _maskutil
    def rle_to_mask(seg):
        s = {"counts": seg["counts"].encode() if isinstance(seg["counts"], str) else seg["counts"],
             "size": seg["size"]}
        return _maskutil.decode(s).astype(np.uint8)
    print("RLE 디코더: pycocotools")
except ImportError:
    def rle_to_mask(seg):
        return _rle_decode_py(seg["counts"], seg["size"])
    print("RLE 디코더: 순수 파이썬 (fallback)")


def seg_to_polygons(seg, h, w, min_area_ratio, eps_ratio):
    '''COCO segmentation(RLE 또는 폴리곤 리스트) → [[x1,y1,x2,y2,...], ...] 픽셀 좌표 폴리곤.'''
    # 이미 폴리곤 형식인 경우 그대로 반환
    if isinstance(seg, list):
        return [list(map(float, p)) for p in seg if len(p) >= 6]

    mask = rle_to_mask(seg)
    if mask.ndim == 3:
        mask = mask[:, :, 0]

    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    min_area = min_area_ratio * h * w
    polys = []
    for c in contours:
        if cv2.contourArea(c) < min_area:
            continue
        approx = cv2.approxPolyDP(c, eps_ratio * cv2.arcLength(c, True), True)
        if len(approx) < 3:
            continue
        polys.append(approx.reshape(-1).astype(float).tolist())
    return polys


def safe_link(src: Path, dst: Path):
    '''Windows 심볼릭 링크 권한 문제(WinError 1314) 회피: 하드링크 → 실패 시 복사.'''
    if dst.exists():
        return
    try:
        os.link(src, dst)
    except Exception:
        shutil.copy2(src, dst)
# Out:
# RLE 디코더: 순수 파이썬 (fallback)

# %% [markdown]
# ## 4. 변환 실행 — YOLO 세그멘테이션 데이터셋 생성

# %%
def convert_split(split: str) -> dict:
    src_dir = SRC_ROOT / split
    ann_path = src_dir / "_annotations.coco.json"
    if not ann_path.exists():
        print(f"[skip] {split}: annotation 파일 없음")
        return {}

    img_out = DST_ROOT / "images" / split
    lbl_out = DST_ROOT / "labels" / split
    img_out.mkdir(parents=True, exist_ok=True)
    lbl_out.mkdir(parents=True, exist_ok=True)

    coco = json.loads(ann_path.read_text(encoding="utf-8"))

    # Roboflow는 supercategory='none'인 더미 카테고리(id=0)를 넣습니다 → 제외 후 0부터 재매핑
    real_cats = [c for c in coco["categories"] if c.get("supercategory") != "none"]
    if not real_cats:
        real_cats = coco["categories"]
    cat2cls = {c["id"]: i for i, c in enumerate(sorted(real_cats, key=lambda x: x["id"]))}
    names = [c["name"] for c in sorted(real_cats, key=lambda x: x["id"])]

    anns_by_img = defaultdict(list)
    for a in coco["annotations"]:
        anns_by_img[a["image_id"]].append(a)

    stat = Counter()
    for im in coco["images"]:
        src_img = src_dir / im["file_name"]
        if not src_img.exists():
            stat["missing_image"] += 1
            continue

        h, w = im["height"], im["width"]
        lines = []
        for a in anns_by_img.get(im["id"], []):
            if a["category_id"] not in cat2cls:
                continue
            polys = seg_to_polygons(a["segmentation"], h, w,
                                    CFG["MIN_AREA_RATIO"], CFG["APPROX_EPS_RATIO"])
            if not polys:
                stat["empty_poly"] += 1
                continue
            cls = cat2cls[a["category_id"]]
            for p in polys:
                # 정규화 + [0,1] 클리핑
                norm = []
                for i in range(0, len(p), 2):
                    norm.append(min(max(p[i] / w, 0.0), 1.0))
                    norm.append(min(max(p[i + 1] / h, 0.0), 1.0))
                lines.append(str(cls) + " " + " ".join(f"{v:.6f}" for v in norm))
                stat["polygons"] += 1

        safe_link(src_img, img_out / im["file_name"])
        (lbl_out / (Path(im["file_name"]).stem + ".txt")).write_text("\n".join(lines), encoding="utf-8")
        stat["images"] += 1
        if not lines:
            stat["background_only"] += 1

    print(f"[{split}] {dict(stat)} | classes={names}")
    return {"names": names, "stat": stat}


DST_ROOT.mkdir(parents=True, exist_ok=True)
results_meta = {s: convert_split(s) for s in SPLITS}
CLASS_NAMES = next((m["names"] for m in results_meta.values() if m), ["water"])
print("\n최종 클래스:", CLASS_NAMES)
# Out:
# [train] {'polygons': 928, 'images': 421} | classes=['water']
# [valid] {'polygons': 132, 'images': 92, 'background_only': 1} | classes=['water']
# [test] {'polygons': 107, 'images': 54} | classes=['water']
#
# 최종 클래스: ['water']

# %% [markdown]
# ## 5. 변환 검증 — 라벨을 이미지 위에 다시 그려보기

# %%
import matplotlib.pyplot as plt

def preview(split="train", n=4, seed=0):
    img_dir = DST_ROOT / "images" / split
    lbl_dir = DST_ROOT / "labels" / split
    files = sorted(img_dir.glob("*.jpg"))
    if not files:
        print("이미지 없음"); return
    random.seed(seed)
    picks = random.sample(files, min(n, len(files)))

    fig, axes = plt.subplots(1, len(picks), figsize=(5 * len(picks), 5))
    axes = np.atleast_1d(axes)
    for ax, f in zip(axes, picks):
        img = cv2.cvtColor(cv2.imread(str(f)), cv2.COLOR_BGR2RGB)
        h, w = img.shape[:2]
        overlay = img.copy()
        lbl = lbl_dir / (f.stem + ".txt")
        n_poly = 0
        if lbl.exists():
            for line in lbl.read_text(encoding="utf-8").splitlines():
                v = line.split()
                if len(v) < 7:
                    continue
                pts = np.array(list(map(float, v[1:])), dtype=np.float32).reshape(-1, 2)
                pts[:, 0] *= w; pts[:, 1] *= h
                cv2.fillPoly(overlay, [pts.astype(np.int32)], (0, 120, 255))
                cv2.polylines(img, [pts.astype(np.int32)], True, (0, 255, 255), 2)
                n_poly += 1
        blended = cv2.addWeighted(overlay, 0.4, img, 0.6, 0)
        ax.imshow(blended); ax.set_title(f"{f.name[:22]}… ({n_poly} poly)", fontsize=9); ax.axis("off")
    plt.tight_layout(); plt.show()

preview("train", n=4)

# %% [markdown]
# ## 6. `data.yaml` 생성

# %%
import yaml

data_yaml = {
    "path": str(DST_ROOT),
    "train": "images/train",
    "val": "images/valid",
    "test": "images/test",
    "names": {i: n for i, n in enumerate(CLASS_NAMES)},
}

YAML_PATH = DST_ROOT / "data.yaml"
YAML_PATH.write_text(yaml.safe_dump(data_yaml, allow_unicode=True, sort_keys=False), encoding="utf-8")
print(YAML_PATH.read_text(encoding="utf-8"))
# Out:
# path: C:\Project\PythonProject\PyTorch001\datasets\water_seg
# train: images/train
# val: images/valid
# test: images/test
# names:
#   0: water

# %% [markdown]
# ## 7. 학습
#
# - `yolo11n-seg.pt`(nano)로 시작 — 8GB VRAM에서 batch 8 / 640px 여유 있게 동작합니다.
# - OOM이 나면 `BATCH`를 4로, 그래도 안 되면 `IMGSZ`를 512로 낮추세요.
# - 수면은 형태 변화가 크고 반사·그림자 영향을 받으므로 **색상 증강(hsv)** 은 유지하고,
#   좌우 반전은 켜되 **상하 반전(flipud)은 0** 으로 둡니다(수면은 항상 아래쪽에 있음).

# %%
from ultralytics import YOLO

def load_model(preferred):
    # yolo26m -> 26s -> 26n 순으로 폴백 (가중치 미존재 / VRAM 부족 대비)
    candidates = [preferred, "yolo26s-seg.pt", "yolo26n-seg.pt"]
    seen = set()
    for name in candidates:
        if name in seen:
            continue
        seen.add(name)
        try:
            m = YOLO(name)
            print(f"[OK] 모델 로드: {name}")
            return m, name
        except Exception as e:
            print(f"[skip] {name} -> {type(e).__name__}: {str(e)[:120]}")
    raise RuntimeError("사용 가능한 세그멘테이션 가중치를 찾지 못했습니다.")


model, USED_MODEL = load_model(CFG["MODEL"])

results = model.train(
    data=str(YAML_PATH),
    epochs=CFG["EPOCHS"],
    imgsz=CFG["IMGSZ"],
    batch=CFG["BATCH"],
    device=0 if torch.cuda.is_available() else "cpu",
    workers=2,
    project=CFG["RUN_PROJECT"],
    name=CFG["RUN_NAME"],
    exist_ok=True,

    # ===== 얼리스톱 =====
    patience=CFG["PATIENCE"],   # fitness 미개선 epoch 수 초과 시 자동 중단
    # ====================

    optimizer="auto",
    cos_lr=True,
    amp=True,
    cache=CFG["CACHE"],

    # 증강 (medium은 용량이 커서 과적합 방지를 강화)
    hsv_h=0.015, hsv_s=0.7, hsv_v=0.4,
    degrees=0.0, translate=0.15, scale=0.5, shear=0.0,
    fliplr=0.5, flipud=0.0,
    mosaic=1.0, close_mosaic=15,
    copy_paste=0.3,             # 세그멘테이션 전용 증강
    erasing=0.2,

    val=True, plots=True, seed=42,
)

SAVE_DIR = Path(results.save_dir)
BEST_PT = SAVE_DIR / "weights" / "best.pt"
print("\n사용 모델:", USED_MODEL)
print("저장 경로:", SAVE_DIR)
print("best.pt  :", BEST_PT, "| exists:", BEST_PT.exists())
# Out:
# [OK] 모델 로드: yolo26m-seg.pt
# New https://pypi.org/project/ultralytics/8.4.115 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.86  Python-3.11.9 torch-2.12.0.dev20260408+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=ram, cfg=None, classes=None, close_mosaic=15, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.3, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=C:\Project\PythonProject\PyTorch001\datasets\water_seg\data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=300, erasing=0.2, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26m-seg.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=water_seg_v3_m, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=40, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=C:\Project\PythonProject\PyTorch001\runs_water_v3, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Project\PythonProject\PyTorch001\runs_water_v3\water_seg_v3_m, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=segment, time=None, tracker=tracktrack.yaml, translate=0.15, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   7995679  ultralytics.nn.modules.head.Segment26        [1, 32, 256, 1, True, [256, 512, 512]]
# YOLO26m-seg summary: 329 layers, 26,969,951 parameters, 26,969,951 gradients, 131.9 GFLOPs
#
# Transferred 890/904 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.20.1 ms, read: 43.031.5 MB/s, size: 34.8 KB)
# train: Scanning C:\Project\PythonProject\PyTorch001\datasets\water_seg\labels\train.cache... 421 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 421/421  0.0s
# train: C:\Project\PythonProject\PyTorch001\datasets\water_seg\images\train\5Q2mNb_jpg.rf.1d87828f749a415abb680b67354a0a3b.jpg: 2 duplicate labels removed
# train: C:\Project\PythonProject\PyTorch001\datasets\water_seg\images\train\car-723-Level2_2_jpg.rf.fb00d925ed3bbb321f79768478dad13e.jpg: 1 duplicate labels removed
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (0.3GB RAM): 100% ━━━━━━━━━━━━ 421/421 1.3Kit/s 0.3s<0.0s
# val: Fast image access  (ping: 0.20.1 ms, read: 42.246.6 MB/s, size: 33.7 KB)
# val: Scanning C:\Project\PythonProject\PyTorch001\datasets\water_seg\labels\valid.cache... 92 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 92/92  0.0s
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.1GB RAM): 100% ━━━━━━━━━━━━ 92/92 1.9Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 144 weight(decay=0.0), 164 weight(decay=0.0005), 164 bias(decay=0.0)
# Plotting labels to C:\Project\PythonProject\PyTorch001\runs_water_v3\water_seg_v3_m\labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to C:\Project\PythonProject\PyTorch001\runs_water_v3\water_seg_v3_m
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       1/300      3.34G       1.23      2.563      3.538    0.01505      2.453          4        640: 100% ━━━━━━━━━━━━ 106/106 1.7it/s 1:010.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8s/it 33.7s0.4s
#                    all         92        132      0.415      0.508      0.429       0.18      0.422      0.515      0.397      0.156
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       2/300      3.33G      1.496      2.399      1.978    0.02008      1.788          6        640: 100% ━━━━━━━━━━━━ 106/106 3.1it/s 34.2s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.0it/s 2.4s0.2s
#                    all         92        132       0.36      0.371      0.277      0.127      0.327      0.371      0.225       0.08
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#       3
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     213/300      3.41G     0.6727      1.001     0.4915    0.00611      0.311          4        640: 100% ━━━━━━━━━━━━ 106/106 3.0it/s 35.4s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 4.5it/s 2.7s0.2s
#                    all         92        132      0.791      0.705       0.71      0.523      0.801      0.731      0.731       0.48
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss   sem_loss  Instances       Size
#     214/300      3.44G     0.7034     0.9608     0.4863   0.006295     0.2974          2        640: 100% ━━━━━━━━━━━━ 106/106 3.1it/s 34.6s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 4.5it/s 2.7s0.2s
#                    all         92        132      0.831      0.709      0.719      0.529       0.86      0.745      0.742      0.482
# EarlyStopping: Training stopped early as no improvement observed in last 40 epochs. Best results observed at epoch 174, best model saved as best.pt.
# To update EarlyStopping(patience=40) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 214 epochs completed in 2.507 hours.
# Optimizer stripped from C:\Project\PythonProject\PyTorch001\runs_water_v3\water_seg_v3_m\weights\last.pt, 54.5MB
# Optimizer stripped from C:\Project\PythonProject\PyTorch001\runs_water_v3\water_seg_v3_m\weights\best.pt, 54.5MB
#
# Validating C:\Project\PythonProject\PyTorch001\runs_water_v3\water_seg_v3_m\weights\best.pt...
# Ultralytics 8.4.86  Python-3.11.9 torch-2.12.0.dev20260408+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# YOLO26m-seg summary (fused): 149 layers, 23,508,239 parameters, 0 gradients, 121.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.9it/s 2.0s0.2s
#                    all         92        132      0.872      0.672      0.744      0.551      0.826      0.727      0.768      0.515
# Speed: 0.4ms preprocess, 8.1ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to C:\Project\PythonProject\PyTorch001\runs_water_v3\water_seg_v3_m
#
# 사용 모델: yolo26m-seg.pt
# 저장 경로: C:\Project\PythonProject\PyTorch001\runs_water_v3\water_seg_v3_m
# best.pt  : C:\Project\PythonProject\PyTorch001\runs_water_v3\water_seg_v3_m\weights\best.pt | exists: True

# %% [markdown]
# ### 7-1. 얼리스톱 동작 확인
#
# `patience`만큼 개선이 없으면 Ultralytics가 자동 중단하고 최고 성능 시점을 `best.pt`로 남깁니다.
# 실제로 몇 epoch에서 멈췄는지, 최고 성능 epoch이 언제였는지 확인하세요.

# %%
import csv as _csv

res_csv = SAVE_DIR / "results.csv"
if res_csv.exists():
    with open(res_csv, encoding="utf-8") as f:
        rows = list(_csv.DictReader(f))
    key = next((k for k in rows[0] if "mAP50-95(M)" in k), None)
    ran = len(rows)
    limit = CFG["EPOCHS"]
    pat = CFG["PATIENCE"]
    if key:
        vals = [float(r[key]) for r in rows]
        best_ep = int(np.argmax(vals)) + 1
        print(f"실행 epoch : {ran} / 상한 {limit}")
        print(f"최고 epoch : {best_ep} (mask mAP50-95 = {max(vals):.4f})")
        print(f"이후 정체  : {ran - best_ep} epoch (patience={pat})")
        print("-> 얼리스톱 작동함" if ran < limit else "-> 상한까지 학습됨. EPOCHS 상향 검토")

        plt.figure(figsize=(7, 4))
        plt.plot(range(1, ran + 1), vals, label="mask mAP50-95")
        plt.axvline(best_ep, color="r", ls="--", label=f"best ep {best_ep}")
        plt.xlabel("epoch"); plt.ylabel("mask mAP50-95")
        plt.legend(); plt.grid(alpha=0.3); plt.tight_layout(); plt.show()
else:
    print("results.csv 없음")
# Out:
# 실행 epoch : 214 / 상한 300
# 최고 epoch : 174 (mask mAP50-95 = 0.5144)
# 이후 정체  : 40 epoch (patience=40)
# -> 얼리스톱 작동함

# %% [markdown]
# ## 8. 검증 — mask mAP 확인

# %%
best = YOLO(str(BEST_PT))
DEV = 0 if torch.cuda.is_available() else "cpu"

m_val = best.val(data=str(YAML_PATH), split="val", imgsz=CFG["IMGSZ"], device=DEV,
                 project=CFG["RUN_PROJECT"], name=CFG["RUN_NAME"] + "_val", exist_ok=True)
print("\n[VAL]  Box  mAP50: %.4f | mAP50-95: %.4f" % (m_val.box.map50, m_val.box.map))
print("[VAL] Mask mAP50: %.4f | mAP50-95: %.4f" % (m_val.seg.map50, m_val.seg.map))

try:
    m_test = best.val(data=str(YAML_PATH), split="test", imgsz=CFG["IMGSZ"], device=DEV,
                      project=CFG["RUN_PROJECT"], name=CFG["RUN_NAME"] + "_test", exist_ok=True)
    print("\n[TEST] Mask mAP50: %.4f | mAP50-95: %.4f" % (m_test.seg.map50, m_test.seg.map))
    print("[TEST] Mask     P: %.4f | R: %.4f" % (m_test.seg.mp, m_test.seg.mr))
except Exception as e:
    print("[test 스킵]", e)

print("\n--- v2 (yolo26n-seg) 기준선 ---")
print("v2 TEST mask mAP50 = 0.6042 | mAP50-95 = 0.3831")
print("v2 VAL  mask mAP50 = 0.7202 | mAP50-95 = 0.5177")
# Out:
# Ultralytics 8.4.86  Python-3.11.9 torch-2.12.0.dev20260408+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# YOLO26m-seg summary (fused): 149 layers, 23,508,239 parameters, 0 gradients, 121.2 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 93.660.7 MB/s, size: 26.0 KB)
# val: Scanning C:\Project\PythonProject\PyTorch001\datasets\water_seg\labels\valid.cache... 92 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 92/92  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.0it/s 2.9s0.6s
#                    all         92        132      0.842      0.674      0.733      0.536      0.817      0.713      0.751      0.501
# Speed: 1.8ms preprocess, 17.3ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to C:\Project\PythonProject\PyTorch001\runs_water_v3\water_seg_v3_m_val
#
# [VAL]  Box  mAP50: 0.7330 | mAP50-95: 0.5365
# [VAL] Mask mAP50: 0.7513 | mAP50-95: 0.5012
# Ultralytics 8.4.86  Python-3.11.9 torch-2.12.0.dev20260408+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Laptop GPU, 8151MiB)
# val: Fast image access  (ping: 0.20.1 ms, read: 38.746.5 MB/s, size: 28.1 KB)
# val: Scanning C:\Project\PythonProject\PyTorch001\datasets\water_seg\labels\test.cache... 54 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 54/54  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1it/s 3.6s1.2ss
#                    all         54        107      0.826      0.577      0.632      0.409      0.799      0.556      0.601       0.39
# Speed: 2.2ms preprocess, 16.0ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to C:\Project\PythonProject\PyTorch001\runs_water_v3\water_seg_v3_m_test
#
# [TEST] Mask mAP50: 0.6008 | mAP50-95: 0.3902
# [TEST] Mask     P: 0.7986 | R: 0.5558
#
# --- v2 (yolo26n-seg) 기준선 ---
# v2 TEST mask mAP50 = 0.6042 | mAP50-95 = 0.3831
# v2 VAL  mask mAP50 = 0.7202 | mAP50-95 = 0.5177

# %% [markdown]
# ### 8-1. 픽셀 단위 IoU / Dice — 이 프로젝트의 진짜 지표
#
# mAP는 **인스턴스 단위** 지표라, 물 한 덩어리를 세 조각으로 나눠 잡으면 점수가 깎입니다.
# 하지만 침수 판정은 마스크를 전부 합쳐 쓰기 때문에 그런 분할은 결과에 영향이 없습니다.
#
# 그래서 **병합된 수면 영역의 픽셀 IoU / Dice**를 따로 측정합니다.
# 발표 자료의 주 지표로는 이 수치가 논리적으로 더 맞습니다.

# %%
def load_gt_mask(label_path, h, w):
    # YOLO-seg 라벨(.txt) -> 병합 GT 마스크
    m = np.zeros((h, w), np.uint8)
    if not label_path.exists():
        return m
    for line in label_path.read_text(encoding="utf-8").splitlines():
        v = line.split()
        if len(v) < 7:
            continue
        pts = np.array(list(map(float, v[1:])), np.float32).reshape(-1, 2)
        pts[:, 0] *= w
        pts[:, 1] *= h
        cv2.fillPoly(m, [pts.astype(np.int32)], 1)
    return m


def predict_mask(bgr, conf=0.25):
    # 인스턴스 마스크를 전부 OR 병합 -> 단일 수면 영역
    h, w = bgr.shape[:2]
    r = best.predict(source=bgr, conf=conf, imgsz=CFG["IMGSZ"], device=DEV, verbose=False)[0]
    pr = np.zeros((h, w), np.uint8)
    if r.masks is not None:
        for m in r.masks.data.cpu().numpy():
            mm = cv2.resize(m.astype(np.float32), (w, h), interpolation=cv2.INTER_LINEAR)
            pr |= (mm > 0.5).astype(np.uint8)
    return pr


def pixel_eval(split="test", conf=0.25, verbose=True):
    img_dir = DST_ROOT / "images" / split
    lbl_dir = DST_ROOT / "labels" / split
    files = sorted(img_dir.glob("*.jpg"))

    inter_t = union_t = gt_t = pr_t = 0
    ious, dices = [], []

    for f in files:
        bgr = cv2.imread(str(f))
        if bgr is None:
            continue
        h, w = bgr.shape[:2]
        gt = load_gt_mask(lbl_dir / (f.stem + ".txt"), h, w)
        pr = predict_mask(bgr, conf)

        i_ = int(np.logical_and(gt, pr).sum())
        u_ = int(np.logical_or(gt, pr).sum())
        inter_t += i_
        union_t += u_
        gt_t += int(gt.sum())
        pr_t += int(pr.sum())
        if u_ > 0:
            ious.append(i_ / u_)
            dices.append(2 * i_ / (int(gt.sum()) + int(pr.sum()) + 1e-9))

    out = {
        "iou": inter_t / max(union_t, 1),
        "dice": float(np.mean(dices)) if dices else 0.0,
        "img_iou": float(np.mean(ious)) if ious else 0.0,
        "precision": inter_t / max(pr_t, 1),
        "recall": inter_t / max(gt_t, 1),
    }
    if verbose:
        print(f"[{split}] n={len(files)} conf={conf}")
        print(f"  전역 IoU        : {out['iou']:.4f}")
        print(f"  이미지평균 IoU  : {out['img_iou']:.4f} (Dice {out['dice']:.4f})")
        print(f"  픽셀 Precision  : {out['precision']:.4f}")
        print(f"  픽셀 Recall     : {out['recall']:.4f}")
    return out


_ = pixel_eval("valid")
px_test = pixel_eval("test")
# Out:
# [valid] n=92 conf=0.25
#   전역 IoU        : 0.7595
#   이미지평균 IoU  : 0.6902 (Dice 0.7758)
#   픽셀 Precision  : 0.8982
#   픽셀 Recall     : 0.8311
# [test] n=54 conf=0.25
#   전역 IoU        : 0.7126
#   이미지평균 IoU  : 0.7220 (Dice 0.8097)
#   픽셀 Precision  : 0.9257
#   픽셀 Recall     : 0.7558

# %% [markdown]
# ### 8-2. conf 임계값 튜닝
#
# v2에서 Recall(0.60)이 Precision(0.74)보다 낮았습니다 — 물을 놓치는 쪽이 문제입니다.
# `conf`를 낮추면 Recall이 올라가므로, **valid에서 픽셀 IoU가 최대가 되는 지점**을 찾아
# 추론 기본값으로 사용합니다. (test로 고르면 안 됩니다)

# %%
sweep = {}
for c in [0.10, 0.15, 0.20, 0.25, 0.35, 0.50]:
    sweep[c] = pixel_eval("valid", conf=c, verbose=False)
    s = sweep[c]
    print(f"conf={c:<5} IoU {s['iou']:.4f} | P {s['precision']:.4f} | R {s['recall']:.4f}")

best_conf = max(sweep, key=lambda k: sweep[k]["iou"])
print(f"\n최적 conf = {best_conf} (valid IoU {sweep[best_conf]['iou']:.4f})")
print("test 재평가:")
px_test = pixel_eval("test", conf=best_conf)

cs = sorted(sweep)
plt.figure(figsize=(7, 4))
plt.plot(cs, [sweep[c]["iou"] for c in cs], "o-", label="IoU")
plt.plot(cs, [sweep[c]["precision"] for c in cs], "s--", label="pixel P")
plt.plot(cs, [sweep[c]["recall"] for c in cs], "^--", label="pixel R")
plt.axvline(best_conf, color="r", ls=":", alpha=0.6)
plt.xlabel("conf threshold")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# conf=0.1   IoU 0.7774 | P 0.8875 | R 0.8623
# conf=0.15  IoU 0.7790 | P 0.8956 | R 0.8568
# conf=0.2   IoU 0.7643 | P 0.8975 | R 0.8374
# conf=0.25  IoU 0.7595 | P 0.8982 | R 0.8311
# conf=0.35  IoU 0.7113 | P 0.9016 | R 0.7711
# conf=0.5   IoU 0.6268 | P 0.9067 | R 0.6700
#
# 최적 conf = 0.15 (valid IoU 0.7790)
# test 재평가:
# [test] n=54 conf=0.15
#   전역 IoU        : 0.7170
#   이미지평균 IoU  : 0.7378 (Dice 0.8324)
#   픽셀 Precision  : 0.9074
#   픽셀 Recall     : 0.7737

# %%
from IPython.display import Image, display

# ultralytics 8.4.86 + polars 조합에서 results.png 생성이 실패할 수 있음
# (ERROR Plotting error ... name 'PyDataFrame' is not defined)
for f in ["results.png", "confusion_matrix_normalized.png",
          "val_batch0_labels.jpg", "val_batch0_pred.jpg"]:
    p = SAVE_DIR / f
    if p.exists():
        print("=" * 20, f)
        display(Image(filename=str(p), width=900))

# results.png가 없으면 results.csv에서 직접 그림
if not (SAVE_DIR / "results.png").exists() and (SAVE_DIR / "results.csv").exists():
    import csv as _csv2
    with open(SAVE_DIR / "results.csv", encoding="utf-8") as fp:
        rows2 = list(_csv2.DictReader(fp))

    def col(sub):
        k = next((k for k in rows2[0] if sub in k), None)
        return [float(r[k]) for r in rows2] if k else None

    fig, ax = plt.subplots(1, 3, figsize=(15, 4))
    for a, (sub, t) in zip(ax, [("train/seg_loss", "train seg_loss"),
                                ("val/seg_loss", "val seg_loss"),
                                ("mAP50-95(M)", "mask mAP50-95")]):
        v = col(sub)
        if v:
            a.plot(v)
            a.set_title(t)
            a.set_xlabel("epoch")
            a.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()
# Out:
# ==================== results.png
# ==================== confusion_matrix_normalized.png
# ==================== val_batch0_labels.jpg
# ==================== val_batch0_pred.jpg

# %% [markdown]
# ## 9. 추론 — 수면 마스크 시각화

# %%
def predict_water(img_path, conf=0.25, show=True):
    '''단일 이미지 추론 → (원본, 통합 수면 마스크, 결과객체)'''
    r = best.predict(source=str(img_path), conf=conf, imgsz=CFG["IMGSZ"],
                     device=0 if torch.cuda.is_available() else "cpu", verbose=False)[0]
    img = cv2.cvtColor(cv2.imread(str(img_path)), cv2.COLOR_BGR2RGB)
    h, w = img.shape[:2]

    water = np.zeros((h, w), dtype=np.uint8)
    if r.masks is not None:
        for m in r.masks.data.cpu().numpy():
            water |= (cv2.resize(m, (w, h), interpolation=cv2.INTER_NEAREST) > 0.5).astype(np.uint8)

    if show:
        vis = img.copy()
        vis[water == 1] = (0.45 * np.array([0, 140, 255]) + 0.55 * vis[water == 1]).astype(np.uint8)
        ratio = water.mean()
        plt.figure(figsize=(11, 6))
        plt.imshow(vis); plt.axis("off")
        plt.title(f"water pixel ratio = {ratio:.3f}  |  detections = {0 if r.masks is None else len(r.masks)}")
        plt.show()
    return img, water, r


# 테스트 셋에서 무작위 2장
test_imgs = sorted((DST_ROOT / "images" / "test").glob("*.jpg"))
for f in random.sample(test_imgs, min(2, len(test_imgs))):
    predict_water(f)

# %% [markdown]
# ## 10. 침수 파이프라인 연동 유틸
#
# 수면 마스크 자체보다 **"차량 바퀴가 얼마나 잠겼는가"** 가 최종 지표이므로,
# 바퀴 bbox와 수면 마스크를 교차시켜 침수율을 계산하는 함수를 함께 둡니다.
# `wheel_boxes`는 2단계(바퀴 검출) 모델의 출력 `[x1, y1, x2, y2]` 리스트를 그대로 넣으면 됩니다.

# %%
def water_line_y(water_mask, x_range=None):
    '''지정 x구간에서 수면의 최상단 y좌표(픽셀). 물이 없으면 None.'''
    m = water_mask if x_range is None else water_mask[:, x_range[0]:x_range[1]]
    ys = np.where(m.any(axis=1))[0]
    return int(ys.min()) if len(ys) else None


def wheel_submersion(water_mask, wheel_box):
    '''바퀴 bbox 내 수면 픽셀 비율 + 수면선 기준 잠김 높이 비율.'''
    x1, y1, x2, y2 = [int(v) for v in wheel_box]
    h, w = water_mask.shape
    x1, x2 = max(0, x1), min(w, x2)
    y1, y2 = max(0, y1), min(h, y2)
    if x2 <= x1 or y2 <= y1:
        return {"pixel_ratio": 0.0, "height_ratio": 0.0, "water_y": None}

    roi = water_mask[y1:y2, x1:x2]
    pixel_ratio = float(roi.mean())

    wy = water_line_y(water_mask, (x1, x2))
    height_ratio = 0.0 if wy is None else float(np.clip((y2 - max(wy, y1)) / (y2 - y1), 0, 1))
    return {"pixel_ratio": round(pixel_ratio, 4),
            "height_ratio": round(height_ratio, 4),
            "water_y": wy}


def level_from_ratio(height_ratio):
    '''바퀴 잠김 비율 → 침수 5단계(0~4). 임계값은 프로젝트 기준에 맞춰 조정하세요.'''
    if height_ratio < 0.05: return 0
    if height_ratio < 0.25: return 1   # 타이어 하단
    if height_ratio < 0.50: return 2   # 휠 림 하단
    if height_ratio < 0.75: return 3   # 휠 림 상단
    return 4                            # 타이어 완전 침수

# --- 사용 예시 (바퀴 검출 모델의 bbox를 넣어 사용) ---
demo = test_imgs[0] if test_imgs else None
if demo:
    img, water, r = predict_water(demo, show=False)
    h, w = water.shape
    dummy_wheel = [int(w * 0.35), int(h * 0.55), int(w * 0.50), int(h * 0.80)]  # 예시용 임시 bbox
    info = wheel_submersion(water, dummy_wheel)
    print(demo.name, info, "→ Level", level_from_ratio(info["height_ratio"]))
# Out:
# C2VtYH_jpg.rf.46970ab88100464c16e1fb06abd0e91b.jpg {'pixel_ratio': 0.2092, 'height_ratio': 0.25, 'water_y': 472} → Level 2

# %% [markdown]
# ### 10-1. 파일명 레벨 라벨로 교차 검증
#
# 파일명이 `car-1008-Level2_1.jpg` 형태라 이미 침수 레벨이 들어있습니다.
# **레벨이 올라갈수록 수면 픽셀 비율이 단조 증가**하면 모델이 물을 제대로 잡고 있다는 근거가 됩니다.
# 발표 자료의 정량 검증 항목으로 그대로 쓸 수 있습니다.

# %%
import re

def level_consistency_check(split="test"):
    imgs = sorted((DST_ROOT / "images" / split).glob("*.jpg"))
    buckets = defaultdict(list)
    for f in imgs:
        m = re.search(r"Level(\d)", f.name)
        if not m:
            continue
        _, water, _ = predict_water(f, show=False)
        buckets[int(m.group(1))].append(float(water.mean()))

    if not buckets:
        print("파일명에 Level 표기가 있는 이미지가 없습니다."); return None

    rows = []
    for lv in sorted(buckets):
        v = np.array(buckets[lv])
        rows.append((lv, len(v), v.mean(), v.std()))
        print(f"Level {lv} | n={len(v):3d} | 수면비율 평균 {v.mean():.4f} (std {v.std():.4f})")

    means = [r[2] for r in rows]
    mono = all(means[i] <= means[i + 1] for i in range(len(means) - 1))
    print("\n단조 증가:", "YES — 모델이 레벨 차이를 반영하고 있습니다"
          if mono else "NO — 임계값/라벨 재점검 필요")
    return rows

rows = level_consistency_check("test")
# Out:
# Level 1 | n= 19 | 수면비율 평균 0.1955 (std 0.0606)
# Level 2 | n= 26 | 수면비율 평균 0.2147 (std 0.1134)
#
# 단조 증가: YES — 모델이 레벨 차이를 반영하고 있습니다

# %%
# 위 결과를 막대그래프로 (발표 슬라이드용)
if rows:
    lv = [r[0] for r in rows]; mu = [r[2] for r in rows]; sd = [r[3] for r in rows]
    plt.figure(figsize=(6, 4))
    plt.bar(lv, mu, yerr=sd, capsize=5, color="#2E86C1", alpha=0.85)
    plt.xlabel("Flood Level (filename label)"); plt.ylabel("Predicted water pixel ratio")
    plt.title("Water ratio vs. annotated flood level"); plt.xticks(lv)
    plt.grid(axis="y", alpha=0.3); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 11. 모델 저장 / 내보내기

# %%
EXPORT_DIR = Path(CFG["RUN_PROJECT"]) / "exported"
EXPORT_DIR.mkdir(parents=True, exist_ok=True)

final_pt = EXPORT_DIR / CFG["EXPORT_NAME"]
shutil.copy2(BEST_PT, final_pt)
print("PT 저장:", final_pt)

# 추론 노트북이 그대로 읽어 쓸 설정 파일
meta = {
    "weights": str(final_pt),
    "model": USED_MODEL,
    "imgsz": CFG["IMGSZ"],
    "best_conf": float(best_conf) if "best_conf" in globals() else 0.25,
    "test_pixel_iou": round(px_test["iou"], 4) if "px_test" in globals() else None,
    "test_pixel_recall": round(px_test["recall"], 4) if "px_test" in globals() else None,
}
meta_path = EXPORT_DIR / "water_seg_v3_meta.json"
meta_path.write_text(json.dumps(meta, ensure_ascii=False, indent=2), encoding="utf-8")
print("메타 저장:", meta_path)
print(json.dumps(meta, ensure_ascii=False, indent=2))

# ONNX (선택)
# print(best.export(format="onnx", imgsz=CFG["IMGSZ"], simplify=True, opset=12))
# Out:
# PT 저장: C:\Project\PythonProject\PyTorch001\runs_water_v3\exported\water_seg_v3_best.pt
# 메타 저장: C:\Project\PythonProject\PyTorch001\runs_water_v3\exported\water_seg_v3_meta.json
# {
#   "weights": "C:\\Project\\PythonProject\\PyTorch001\\runs_water_v3\\exported\\water_seg_v3_best.pt",
#   "model": "yolo26m-seg.pt",
#   "imgsz": 640,
#   "best_conf": 0.15,
#   "test_pixel_iou": 0.717,
#   "test_pixel_recall": 0.7737
# }
